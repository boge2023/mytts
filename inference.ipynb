# %%
import requests
import json
import base64
import IPython.display as ipd
import utils

url = 'http://localhost:9000/tts/t2s_bin'
data = {"text": "欸，我没事儿，放心吧，不会影响近期的演出","speaker_id": "zh_female_speaker_1"}
res = requests.post(url, json=data)
audio_base64 = res.json()['data']
audio = base64.b64decode(audio_base64)
hps = utils.get_hparams_from_file("./checkpoint/config.json")
ipd.display(ipd.Audio(audio, rate=hps.data.sampling_rate))
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): localhost:9000
# DEBUG:urllib3.connectionpool:http://localhost:9000 "POST /tts/t2s_bin HTTP/1.1" 200 238349
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
